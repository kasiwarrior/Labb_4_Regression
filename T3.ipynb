# %%
3:1
the grid is 20X20
are= 400

# %%
we countet halv squre as 0,5 and the ones almost filled as 1
green= prox  83 
red= aporx 41 
blue = aprox 53

# %%
3:2
probabilty of A
p(a)=are(A)/400
83/400
we count the squares by hand

p(a)= approx 0.208

# %%
task 3.3
probabilty of B 
p(B)= are(B)/400
53/400
p(B)= approx 0,133

# %%
3.4
probabilty of C 
p(C)= are(C)/400
41/400

p(C)= approx 0.103

# %%
3:5 
P(A∣C)= 0
they only touch its on the border and you can only count
one whole squre

# %%
3:6
P(B∣C)
6.5/41
P(B∣C)= approx 0,159

i could count more then one whole squre on these regions 
so they do overleap

# %%
3:7
P(C∣B) (Bayes Theorem)
P(C∣B)=P(B)P(B∣C)P(C)​

P(C∣B) = 0.159 X 0.103 / 0.133

P(C∣B)= approx 0.123

# %%
Reflection on Task 3

I liked Task 3 because it made probability and Bayes’ theorem more interactive and intuitive.
 By estimating areas manually on the grid, the formulas became easier to understand instead of just something to memorize.
Doing the calculations by hand helped me better remember how conditional probability works and how Bayes’ theorem relates
 different probabilities to each other.
